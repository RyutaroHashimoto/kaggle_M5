# %% [markdown]
# # 2 Data Preprocessing (Sales)

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import pickle

# %%
# Read dataset
sales_test_val = pd.read_pickle('output/sales_test_val.pkl')

# %%
sales_test_val.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  d_1935  d_1936  \
# 0       CA    0    0    0    0  ...       2       4       0       0       0
# 1       CA    0    0    0    0  ...       0       1       2       1       1
# 2       CA    0    0    0    0  ...       1       0       2       0       0
# 3       CA    0    0    0    0  ...       1       1       0       4       0
# 4       CA    0    0    0    0  ...       0       0       0       2       1
#
#    d_1937  d_1938  d_1939  d_1940  d_1941
# ...

# %%
sales_test_val = sales_test_val.drop(sales_test_val.columns[1:6], axis=1)
sales_test_val = sales_test_val.set_index('id')
sales_test_val = sales_test_val.transpose()

# %%
sales_test_val.head()
# Out:
# id   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_002_CA_1_evaluation  \
# d_1                              0                              0
# d_2                              0                              0
# d_3                              0                              0
# d_4                              0                              0
# d_5                              0                              0
#
# id   HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_004_CA_1_evaluation  \
# d_1                              0                              0
# d_2                              0                              0
# d_3                              0                              0
# d_4                              0                              0
# d_5                              0                              0
#
# id   HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_006_CA_1_evaluation  \
# d_1                              0                              0
# ...

# %%
sales_test_val.transpose()
# Out:
#                                d_1  d_2  d_3  d_4  d_5  d_6  d_7  d_8  d_9  \
# id
# HOBBIES_1_001_CA_1_evaluation    0    0    0    0    0    0    0    0    0
# HOBBIES_1_002_CA_1_evaluation    0    0    0    0    0    0    0    0    0
# HOBBIES_1_003_CA_1_evaluation    0    0    0    0    0    0    0    0    0
# HOBBIES_1_004_CA_1_evaluation    0    0    0    0    0    0    0    0    0
# HOBBIES_1_005_CA_1_evaluation    0    0    0    0    0    0    0    0    0
# ...                            ...  ...  ...  ...  ...  ...  ...  ...  ...
# FOODS_3_823_WI_3_evaluation      0    0    2    2    0    3    1    4    1
# FOODS_3_824_WI_3_evaluation      0    0    0    0    0    5    0    1    1
# FOODS_3_825_WI_3_evaluation      0    6    0    2    2    4    1    8    5
# FOODS_3_826_WI_3_evaluation      0    0    0    0    0    0    0    0    0
# FOODS_3_827_WI_3_evaluation      0    0    0    0    0    0    0    0    0
#
# ...

# %%
sales_test_val.to_pickle('dataset/simple_matrix.pkl')
